# %%
# Dependencies and Setup
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem
# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load
Mouse_metadata ='data/Mouse_metadata.csv'
Study_results ='data/Study_results.csv'

# Read the mouse data and the study results
Mouse_metadata_df=pd.read_csv(Mouse_metadata)
Study_results_df=pd.read_csv(Study_results)

# Combine the data into a single dataset
combined_data = pd.merge(Mouse_metadata_df, Study_results_df,on="Mouse ID", how = "left")
combined_data.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
Grouped_data_mean= combined_data.groupby(['Drug Regimen','Timepoint']).mean()["Tumor Volume (mm3)"]
Grouped_data_mean= pd.DataFrame(Grouped_data_mean)
Grouped_data_mean= Grouped_data_mean.reset_index()
Grouped_data_mean.head()
# Out:
#   Drug Regimen  Timepoint  Tumor Volume (mm3)
# 0    Capomulin          0           45.000000
# 1    Capomulin          5           44.266086
# 2    Capomulin         10           43.084291
# 3    Capomulin         15           42.064317
# 4    Capomulin         20           40.716325

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
Grouped_data_sem= combined_data.groupby(['Drug Regimen','Timepoint']).sem()["Tumor Volume (mm3)"]
Grouped_data_sem= pd.DataFrame(Grouped_data_sem)
Grouped_data_sem_Error= Grouped_data_sem.reset_index()
Grouped_data_sem_Error.head()
# Out:
#   Drug Regimen  Timepoint  Tumor Volume (mm3)
# 0    Capomulin          0            0.000000
# 1    Capomulin          5            0.448593
# 2    Capomulin         10            0.702684
# 3    Capomulin         15            0.838617
# 4    Capomulin         20            0.909731

# %%
# Minor Data Munging to Re-Format the Data Framesc
# Grouped_data_mean=Grouped_data_mean.reset_index()
Grouped_data_mean_pivot=Grouped_data_mean.pivot(index="Timepoint",columns="Drug Regimen")["Tumor Volume (mm3)"]

Grouped_data_sem_pivot=Grouped_data_sem_Error.pivot(index="Timepoint",columns="Drug Regimen")["Tumor Volume (mm3)"]
# Preview that Reformatting worked
Grouped_data_mean_pivot.head()
# Out:
# Drug Regimen  Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol  \
# Timepoint
# 0             45.000000  45.000000  45.000000  45.000000  45.000000
# 5             44.266086  46.503051  46.541247  47.389175  46.796098
# 10            43.084291  48.285125  49.403909  49.582269  48.694210
# 15            42.064317  50.094055  51.296397  52.399974  50.933018
# 20            40.716325  52.157049  53.197691  54.920935  53.644087
#
# Drug Regimen    Placebo   Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0             45.000000  45.000000  45.000000  45.000000  45.000000
# 5             47.125589  47.248967  43.944859  47.470830  46.851818
# 10            49.423329  49.101541  42.531957  49.335368  48.689881
# 15            51.359742  51.067318  41.495061  51.448025  50.779059
# 20            54.364417  53.346737  40.238325  53.970080  53.170334

# %%
# Generate the Plot (with Error Bars)

Capomulin_error = Grouped_data_sem_Error.loc[Grouped_data_sem_Error["Drug Regimen"] == "Capomulin", "Tumor Volume (mm3)"]
Infubinol_error = Grouped_data_sem_Error.loc[Grouped_data_sem_Error["Drug Regimen"] == "Infubinol", "Tumor Volume (mm3)"]
Ketapril_error = Grouped_data_sem_Error.loc[Grouped_data_sem_Error["Drug Regimen"] == "Ketapril", "Tumor Volume (mm3)"]
Placebo_error = Grouped_data_sem_Error.loc[Grouped_data_sem_Error["Drug Regimen"] == "Placebo", "Tumor Volume (mm3)"]
Time = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45]


plt.errorbar(Grouped_data_mean_pivot.index, Grouped_data_mean.pivot["Capomulin"],
            yerr=Grouped_data_sem_Error_pivot["Capomulin"],color="r",marker="o",markersize=5,
             linestyle="dashed",linewidth=0.5)

plt.errorbar(Grouped_data_mean_pivot.index, Grouped_data_mean.pivot["Infubinol"],
            yerr=Grouped_data_sem_Error_pivot["Infubinol"],color="b",marker="^",markersize=5,
             linestyle="dashed",linewidth=0.5)

plt.errorbar(Grouped_data_mean_pivot.index, Grouped_data_mean.pivot["Ketapril"],
            yerr=Grouped_data_sem_Error_pivot["Ketapril"],color="g",marker="s",markersize=5,
             linestyle="dashed",linewidth=0.5)

plt.errorbar(Grouped_data_mean_pivot.index, Grouped_data_mean.pivot["Placebo"],
            yerr=Grouped_data_sem_Error_pivot["Placebo"],color="k",marker="d",markersize=5,
             linestyle="dashed",linewidth=0.5)

plt.title("Tumor response to treatment")
plt.ylabel("Tumor volume (mm3)")
plt.xlabel("Time(Days)")
plt.grid(axis="y")
plt.legend(["Capomulin","Infubinol","Ketapril","Placebo"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c34c8846e42c> in <module>
#       8
#       9
# ---> 10 plt.errorbar(Grouped_data_mean_pivot.index, Grouped_data_mean.pivot["Capomulin"],
#      11             yerr=Grouped_data_sem_Error_pivot["Capomulin"],color="r",marker="o",markersize=5,
#      12              linestyle="dashed",linewidth=0.5)
#
# TypeError: 'method' object is not subscriptable

# %% [markdown]
# ![Tumor Response to Treatment](../Images/treatment.png)

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
Met_mean= combined_data.groupby(['Drug Regimen','Timepoint']).mean()["Metastatic Sites"]
Met_mean= pd.DataFrame(Met_mean)
Met_mean= Met_mean.reset_index()
Met_mean.head()
# Out:
#   Drug Regimen  Timepoint  Metastatic Sites
# 0    Capomulin          0          0.000000
# 1    Capomulin          5          0.160000
# 2    Capomulin         10          0.320000
# 3    Capomulin         15          0.375000
# 4    Capomulin         20          0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
Met_sem= combined_data.groupby(['Drug Regimen','Timepoint']).sem()["Metastatic Sites"]
Met_sem= pd.DataFrame(Met_sem)
Met_sem= Met_sem.reset_index()
Met_sem.head()
# Out:
#   Drug Regimen  Timepoint  Metastatic Sites
# 0    Capomulin          0          0.000000
# 1    Capomulin          5          0.074833
# 2    Capomulin         10          0.125433
# 3    Capomulin         15          0.132048
# 4    Capomulin         20          0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames
Mungled_data = Met_mean.pivot(index="Timepoint",columns="Drug Regimen")["Metastatic Sites"]
Mungled_data = Met_sem.pivot(index="Timepoint",columns="Drug Regimen")["Metastatic Sites"]
Mungled_data.head()
# Out:
# Drug Regimen  Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0              0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5              0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10             0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15             0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20             0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
#
# Drug Regimen  Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0             0.000000  0.000000  0.000000   0.000000
# 5             0.095219  0.066332  0.093618   0.077709
# 10            0.105690  0.090289  0.131277   0.109109
# 15            0.136377  0.115261  0.163577   0.111677
# 20            0.171499  0.119430  0.222607   0.166378

# %%
# Generate the Plot (with Error Bars)
Capomulin_error = Met_sem.loc["Drug Regimen"] == ["Capomulin", "Metastatic Sites"]
Infubinol_error = Met_sem.loc['Drug Regimen'] == ["Infubinol", "Metastatic Sites"]
Ketapril_error = Met_sem.loc["Drug Regimen"] == ["Ketapril", "Metastatic Sites"]
Placebo_error = Met_sem.loc["Drug Regimen"] == ["Placebo", "Metastatic Sites"]
Time =[0, 10, 15, 20, 25, 30, 35, 40, 45, 50]

plt.errorbar(Time, Mungled_data["Capomulin"] , yerr= Capomulin_error, label= "Capomulin", marker= "o", color="red", linestyle='--')
plt.errorbar(Time, Mungled_data["Infubinol"] , yerr= Infubinol_error, label= "Infubinol", marker= "^", color="blue", linestyle='--')
plt.errorbar(Time, Mungled_data["Ketapril"] , yerr= Ketapril_error, label= "Ketapril", marker= "D", color="black", linestyle='--')
plt.errorbar(Time, Mungled_data["Placebo"] , yerr= Placebo_error, label= "Placebo", marker= "s", color="green", linestyle='--')
plt.legend(["Capomulin","Infubinol","Ketapril","Placebo"])
plt.title("Metastatic spread During Treatment ")
plt.xlabel("Treatment Duration (Days)")
plt.ylabel("Met.Sites")
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Drug Regimen'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-743e4c7f9ed9> in <module>
#       1 # Generate the Plot (with Error Bars)
# ----> 2 Capomulin_error = Met_sem.loc["Drug Regimen"] == ["Capomulin", "Metastatic Sites"]
# ...

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
Group_data = combined_data.groupby(["Drug Regimen", "Timepoint"])
Count_Mice_Data = Group_data["Mouse ID"].count()

# Convert to DataFrame
Mice_data = pd.DataFrame(Count_Mice_Data).reset_index()

# renaming the column name Mouse ID to Mouse Count 
renamed_Mice_data = Mice_data.rename(columns={"Mouse ID": "Mouse Count"})

# Preview DataFrame
renamed_Mice_data.head()
# Out:
#   Drug Regimen  Timepoint  Mouse Count
# 0    Capomulin          0           25
# 1    Capomulin          5           25
# 2    Capomulin         10           25
# 3    Capomulin         15           24
# 4    Capomulin         20           23

# %%
# Minor Data Munging to Re-Format the Data Frames
Mungled_Mice_data = Mice_data.pivot(index = 'Timepoint', columns ='Drug Regimen', values = 'Mouse ID')
# Preview the Data Frame
Mungled_Mice_data
# Out:
# Drug Regimen  Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                    25        25         25        25        25       25
# 5                    25        21         25        23        23       24
# 10                   25        20         21        22        21       24
# 15                   24        19         21        19        21       20
# 20                   23        18         20        19        20       19
# 25                   22        18         18        19        18       17
# 30                   22        16         17        18        15       15
# 35                   22        14         12        17        15       14
# 40                   21        14         10        15        15       12
# 45                   21        13          9        11        13       11
#
# Drug Regimen  Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                   26        25        24         25
# ...

# %%
# Generate the Plot (Accounting for percentages)
Time = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45]
plt.plot(Time, (Mungled_Mice_data["Capomulin"]/25)*100 , label= "Capomulin", marker= "o", color="red", linestyle='--')
plt.plot(Time, (Mungled_Mice_data["Infubinol"]/25)*100 , label= "Infubinol", marker= "^", color="blue", linestyle='--')
plt.plot(Time, (Mungled_Mice_data["Ketapril"]/25)*100 , label= "Ketapril", marker= "D", color="black", linestyle='--')
plt.plot(Time, (Mungled_Mice_data["Placebo"]/25)*100 , label= "Placebo", marker= "s", color="green", linestyle='--')
plt.legend()
plt.title("Survival During Treatment")
plt.xlabel("Time (Days)")
plt.ylabel("Survival Rate (%) ")
plt.grid()
plt.savefig("Images/Survival_Rate.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-3ef6936ee496> in <module>
#      10 plt.ylabel("Survival Rate (%) ")
#      11 plt.grid()
# ---> 12 plt.savefig("Images/Survival_Rate.png")
#      13 plt.show()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ...

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
Intial_tumor_volume = 45
Percent_Change = ((Mungled_data.loc[45, :] - Intial_tumor_volume)/Intial_tumor_volume)*100

# Display the data to confirm
Percent_Change
# Out:
# Drug Regimen
# Capomulin   -99.549798
# Ceftamin    -99.364219
# Infubinol   -99.312622
# Ketapril    -99.380618
# Naftisol    -99.219768
# Placebo     -99.323911
# Propriva    -99.047619
# Ramicane    -99.577286
# Stelasyn    -99.202084
# Zoniferol   -99.363555
# Name: 45, dtype: float64

# %%
# Splice the data between passing and failing drugs
passing_drugs_list = []
failing_drugs_list = []
index_passing_drugs_list = []
index_failing_drugs_list = []
for j,elements in tuple_Percent_Change_list :
    if elements > 0 :
        passing_drug = elements
        passing_drugs_list.append(elements)
        index_passing_drugs_list.append(j)
    else :
        failing_drugs = elements
        failing_drugs_list.append(elements)
        index_failing_drugs_list.append(j)
passing_drugs = list(zip(index_passing_drugs_list, passing_drugs_list))
failing_drugs = list(zip(index_failing_drugs_list, failing_drugs_list))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-86e89acc50e7> in <module>
#       4 index_passing_drugs_list = []
#       5 index_failing_drugs_list = []
# ----> 6 for j,elements in tuple_Percent_Change_list :
#       7     if elements > 0 :
#       8         passing_drug = elements
#
# NameError: name 'tuple_Percent_Change_list' is not defined

# %%
fig, ax = plt.subplots()
y_value1 = [Percent_Change["Infubinol"], Percent_Change["Ketapril"], Percent_Change["Placebo"]]
x_axis1 = [0]
x_axis2 = [1, 2, 3]


bars1 = ax.bar(x_axis1, Percent_Change["Capomulin"], color='g', alpha=0.8, align="edge", width = -1)
bars2 = ax.bar(x_axis2, y_value1 , color='r', alpha=0.8, align="edge", width = -1)
x_labels = ["Capomulin", "Infubinol", "Ketapril", "Placebo"]

plt.setp(ax, xticks=[0, 1, 2, 3], xticklabels=["Capomulin", "Infubinol", "Ketapril", "Placebo"],
        yticks=[-20, 0, 20, 40, 60])
ax.set_ylabel('% Tumor Volume Change')
ax.set_title('Tumor Change Over 45 Day Treatment')
ax.grid()

# Use functions to label the percentages of changes
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2, .1*height, "%d" %int(height)+ "%",
                ha='center', va='top', color="white")

# Call functions to implement the function calls     
autolabel(bars1)
autolabel(bars2)
fig.tight_layout()

# Save the Figure
plt.savefig("Images/Percentage_Tumor_Volume_Change.png")

# Show the Figure
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-46829d3abc69> in <module>
#      28
#      29 # Save the Figure
# ---> 30 plt.savefig("Images/Percentage_Tumor_Volume_Change.png")
#      31
#      32 # Show the Figure
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ...
